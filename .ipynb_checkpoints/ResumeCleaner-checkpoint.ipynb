# %%
import pymongo as mongo
from pymongo import MongoClient
import re
import nltk
from nltk.corpus import stopwords

# %%
con = mongo.MongoClient(host='127.0.0.1', port=3001)
db = con['meteor']
resume = db['resume']
result = resume.find()
singleResume = result[0]['Content']
# for record in result:
#     print(record)
#     print(record['Name']," ",record['Content'])

# %%
def cleanResume(result):
    
    for record in result:
        content = singleResume
#         content = record['Content']
        lines = []
        
        content = content.decode("utf-8") #Decoding the content to string from byte
        for line in content.splitlines(): # removing spaces from the content 
            currentWords = line.strip()
            print(currentWords)
            currentWords = currentWords.split(' ') #converting the content to tokens
            phrases = currentWords
            currentWords[:] = [word.split(" ") for word in currentWords] #Removing 
#             for phrase in phrases : 
#                 phrase[0] = re.sub("[^a-zA-Z.+3]"," ", phrase[0])
#                 print(phrase[0])
        
#             for word in currentWords :
#                 word = word.split(" ")
                
#             phrases = (word.split(" ") for word in currentWords)
            
#             lines.append(line.strip())
        
            #         lines = (line.strip() for line in text.splitlines())
#         chunks = (phrase.strip() for line in lines for phrase in line.split("  ")
        
#         phrase.strip() for line in lines for phrase in line.split("  ")
        break
cleanResume(result)
# Out:
# AMRUT
# SHENOY
#
#
#
# Park
# Point
# Dr
# .
#
# Rochester
# NY
#
#     3
#
# in.linkedin.com in amrutshn
#
# aas   3 rit.edu
#
#
#
#
#
# Objective
# Seeking
# a
# Co
#
# op
# position
# in
# the
# field
# of
# Software
# Development
# for
# Spring Summer
#
# .
# Education
# MS
# Computer
# Science
# Rochester
# Institute
# of
# Technology
#  Aug
#
# Dec
#
#
# Big
# Data
# Analytics
#
# Data
#
# driven
# Knowledge
# Discovery
#
# Foundations
# of
# Computer
# Networks
#
# Foundations
# of
# Algorithms
#
# Adv.
# Object
#
# Oriented
# Programming
# Concepts
#
# Adv.
# Computational
# Problem
# Solving
#
# Foundations
# of
# Computer
# Vision
# Bachelor
# of
# Computer
# Engineering
# University
# of
# Mumbai
#  Aug
#
# May
#    3
# Analysis
# of
# Algorithms
#
# Design
#
# Data
# Warehousing
#
# Mining
#  ETL
# OLAP
#
# Operating
# System
#
# Comp
# uter
# Networks
#
# Syste
# m
# Security
# Technical
# Skills
# Languages
#
# Java
# Python
# JavaScript
#
# C
# C++
# Web
# ...
